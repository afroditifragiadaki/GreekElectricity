# %% [markdown]
# # Electricity Tariff Data Analysis
# This notebook analyzes electricity tariffs data scraped from the Greek energy provider website.

# %%
import pandas as pd

# Load data
df = pd.read_csv("electricity_tariffs.csv")
df.head()
# Out:
#                                    Πάροχος  Έτος  Μήνας  \
# 0                                PROTERGIA  2024      8
# 1                                    ΖΕΝΙΘ  2024     10
# 2                                  ΕΛΙΝΟΙΛ  2025      1
# 3  ΦΥΣΙΚΟ ΑΕΡΙΟ ΕΛΛΗΝΙΚΗ ΕΤΑΙΡΙΑ ΕΝΕΡΓΕΙΑΣ  2024      9
# 4  ΦΥΣΙΚΟ ΑΕΡΙΟ ΕΛΛΗΝΙΚΗ ΕΤΑΙΡΙΑ ΕΝΕΡΓΕΙΑΣ  2024     10
#
#                Ονομασία Τιμολογίου                        Πάγιο (€/μήνα)  \
# 0                    Value Student                                  9.90
# 1           Power Home Smart Night                                  5.00
# 2             Power On! Hybrid 100  0KWh - 100KWh   7.90 101KWh +   0.00
# 3      Ρεύμα MAXI Home Super Save+                                  6.00
# 4  Ρεύμα MAXI Home Super Save+ Oct                                  6.00
#
#                       Τελική Τιμή Προμήθειας (€/ΚWh)  \
# 0                                              0.001
# 1                                            0.13227
# ...
